# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pickle

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge


from sklearn.metrics import mean_squared_error

# %%
df = pd.read_parquet('./data/green_tripdata_2025-01.parquet')

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1         2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2         2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3         2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4         2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           235              1.0           5.93
# 1         1.0           166            75              1.0           1.32
# 2         5.0           171            73              1.0           0.41
# 3         1.0            74           223              1.0           4.12
# 4         1.0            66           158              1.0           4.71
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
#Test data in Line 1
df['lpep_pickup_datetime'].iloc[1]
# Out:
# Timestamp('2025-01-01 00:19:59')

# %%
#Transform string to int using pandas method to_datetime
df.lpep_pickup_datetime = pd.to_datetime (df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime (df.lpep_dropoff_datetime)

# %%
#ADD new column Duration in minutes
df['duration'] =df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1             2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2             2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3             2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4             2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
# ...         ...                  ...                   ...                ...
# 48321         2  2025-01-31 19:36:00   2025-01-31 20:05:00               None
# 48322         2  2025-01-31 20:33:00   2025-01-31 20:41:00               None
# 48323         2  2025-01-31 21:09:00   2025-01-31 21:30:00               None
# 48324         2  2025-01-31 22:22:00   2025-01-31 22:25:00               None
# 48325         2  2025-01-31 22:15:00   2025-01-31 22:22:00               None
#
# ...

# %%
#Using describe method from Pandas we can check stats fort column
df.duration.describe()
# Out:
# count    48326.000000
# mean        19.955195
# std         93.924039
# min          0.000000
# 25%          7.200000
# 50%         11.250000
# 75%         16.983333
# max       1439.650000
# Name: duration, dtype: float64

# %%
sns.distplot (df.duration)
# Out:
# /tmp/ipykernel_30857/3082850440.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (df.duration)
# <Axes: xlabel='duration', ylabel='Density'>

# %%
#check whats the percentages of trips between 1 to 60 minutes
((df.duration >=1) & (df.duration<=60)).mean()
# Out:
# np.float64(0.9582212473616687)

# %%
df = df[((df.duration >=1) & (df.duration<=60))]

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1             2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2             2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3             2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4             2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
# ...         ...                  ...                   ...                ...
# 48321         2  2025-01-31 19:36:00   2025-01-31 20:05:00               None
# 48322         2  2025-01-31 20:33:00   2025-01-31 20:41:00               None
# 48323         2  2025-01-31 21:09:00   2025-01-31 21:30:00               None
# 48324         2  2025-01-31 22:22:00   2025-01-31 22:25:00               None
# 48325         2  2025-01-31 22:15:00   2025-01-31 22:22:00               None
#
# ...

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# %%
df[categorical].dtypes
# Out:
# PULocationID    int32
# DOLocationID    int32
# dtype: object

# %%
#Transform int to string(objects)
df[categorical] = df[categorical].astype(str)
# Out:
# /tmp/ipykernel_30857/217493709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)

# %%
#transform our numerical and categorical data into dictionary
df[categorical + numerical].iloc[:10].to_dict(orient='records')
# Out:
# [{'PULocationID': '75', 'DOLocationID': '235', 'trip_distance': 5.93},
#  {'PULocationID': '166', 'DOLocationID': '75', 'trip_distance': 1.32},
#  {'PULocationID': '171', 'DOLocationID': '73', 'trip_distance': 0.41},
#  {'PULocationID': '74', 'DOLocationID': '223', 'trip_distance': 4.12},
#  {'PULocationID': '66', 'DOLocationID': '158', 'trip_distance': 4.71},
#  {'PULocationID': '260', 'DOLocationID': '260', 'trip_distance': 4.26},
#  {'PULocationID': '7', 'DOLocationID': '202', 'trip_distance': 2.0},
#  {'PULocationID': '166', 'DOLocationID': '244', 'trip_distance': 2.09},
#  {'PULocationID': '166', 'DOLocationID': '151', 'trip_distance': 0.95},
#  {'PULocationID': '75', 'DOLocationID': '236', 'trip_distance': 0.66}]

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 138921 stored elements and shape (46307, 449)>

# %%
target = 'duration'
y_train = df[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)
sns.distplot (y_pred , label='prediction')
sns.distplot (y_train , label='actual')

plt.legend()
# Out:
# /tmp/ipykernel_30857/1061427136.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (y_pred , label='prediction')
# /tmp/ipykernel_30857/1061427136.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (y_train , label='actual')

# %%
#Evaluation of training performance using mean square error
rmse = np.sqrt(mean_squared_error(y_train, y_pred))
print(rmse)
# Out:
# 6.704280605770969

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2025-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2025-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (46307, 44218)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
df_val
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2025-02-01 00:12:15   2025-02-01 00:15:48                  N
# 1             2  2025-01-31 23:57:05   2025-02-01 00:24:24                  N
# 2             2  2025-02-01 00:24:26   2025-02-01 00:49:54                  N
# 3             1  2025-02-01 00:17:15   2025-02-01 00:25:56                  N
# 4             2  2025-02-01 00:17:36   2025-02-01 00:26:36                  N
# ...         ...                  ...                   ...                ...
# 46616         2  2025-02-28 22:35:00   2025-02-28 23:10:00               None
# 46617         2  2025-02-28 23:40:00   2025-02-28 23:55:00               None
# 46618         2  2025-02-28 23:34:00   2025-02-28 23:48:00               None
# 46619         2  2025-02-28 23:52:00   2025-03-01 00:05:00               None
# 46620         2  2025-02-28 23:04:00   2025-02-28 23:17:00               None
#
# ...

# %%
categorical = ['PU_DO'] #'PULocationID','DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

rmse1 =np.sqrt(mean_squared_error(y_val, y_pred))
print(rmse1)
# Out:
# 6.098881864144634

# %%
with open ('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv,lr) , f_out)

# %%
lr = Lasso(0.001)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

rmse2 =np.sqrt(mean_squared_error(y_val, y_pred))
print(rmse2)
# Out:
# 6.620710124139644
